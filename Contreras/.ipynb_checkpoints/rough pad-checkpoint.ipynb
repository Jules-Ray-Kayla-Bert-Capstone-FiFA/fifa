# %%
import os
import json
from typing import Dict, List, Optional, Union, cast
import requests
import pandas as pd

import unicodedata
import re
import json

import acquire

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
from wordcloud import WordCloud

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer
from sklearn.cluster import KMeans

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import f_regression 


from math import sqrt
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures


import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filter="ignore"

from bs4 import BeautifulSoup
import prepare
import plotly.express as px

# %% [markdown]
# ***

# %% [markdown]
# # `Acquire` Data.

# %%
df = acquire.get_fifa_data()
# Out:
# /var/folders/dc/8rtfvpyj2mb6mqbnfkf5dl400000gn/T/ipykernel_19914/1900469672.py:1: DtypeWarning: Columns (81,85,104) have mixed types.Specify dtype option on import or set low_memory=False.
#   df = acquire.get_fifa_data()

# %% [markdown]
# # `Explore` And `Prep` Data

# %%
#forces dataframe to show every columns
pd.set_option('display.max_columns', None)
df
# Out:
#         sofifa_id                                         player_url  \
# 0          158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          188545  https://sofifa.com/player/188545/robert-lewand...
# 2           20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3          190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4          192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...           ...                                                ...
# 142074     220806  https://sofifa.com/player/220806/ellis-redman/...
# 142075     225509  https://sofifa.com/player/225509/aaron-collins...
# 142076     201197  https://sofifa.com/player/201197/paul-tisdale/...
# 142077     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 142078     222947  https://sofifa.com/player/222947/tom-davies/15...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
#add 0 values to non goal keeper players
#df['goalkeeping_speed'].fillna("0", inplace = True)

# %%
#forces dataframe to show every columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ***

# %% [markdown]
# # Columns That Have Null Values

# %%
na = df.isna().sum() > 0
na[na]
# Out:
# value_eur                    True
# wage_eur                     True
# club_team_id                 True
# club_name                    True
# league_name                  True
# league_level                 True
# club_position                True
# club_jersey_number           True
# club_loaned_from             True
# club_joined                  True
# club_contract_valid_until    True
# nation_team_id               True
# nation_position              True
# nation_jersey_number         True
# release_clause_eur           True
# player_tags                  True
# player_traits                True
# pace                         True
# shooting                     True
# passing                      True
# dribbling                    True
# defending                    True
# physic                       True
# mentality_composure          True
# goalkeeping_speed            True
# lw                           True
# rw                           True
# ...

# %% [markdown]
# `Takeaways:`
# - Over 25 columns have null values and we need to address them.

# %% [markdown]
# ***

# %% [markdown]
# ## Taking a look at our null values:

# %% [markdown]
# # `value_eur`,`wage_eur`, & `club_team_id`.

# %%
#df[df.value_eur.isnull()]

# %% [markdown]
# `Takeaways:`
# - we might have to consider removing these players because they would corrupt our data considering their wage information is missing and would not add any value to our model.

# %%
#df[df.wage_eur.isnull()]

# %% [markdown]
# `Takeaways:`
# - we might have to consider removing these players because they would corrupt our data considering their value information is missing and would not add any value to our model.

# %%
#df[df.club_team_id.isnull()]

# %% [markdown]
# `Takeaways:`
# - we might have to consider removing these players because there club id is important information that we need to conclude their club budget.

# %%
#df[df.league_name.isnull()]

# %% [markdown]
# `Takeaways:`
# - we might have to consider removing these players because the leage that they play in is important and can give us valuable information that needs to be categorized.

# %% [markdown]
# # `club_position`, `club_joined`, & `club_contract_valid_until`.

# %%
#df[df.club_position.isnull()]

# %%
#df[df.club_joined.isnull()]

# %%
#df[df.club_contract_valid_until.isnull()]

# %% [markdown]
# `takeaways:`
# - Club_position, club_joined, & club_contract_valid_until all seem to have similar payers with null values.
# - We will be dropping these rows to better benefit our exploration and our modeling.

# %% [markdown]
# # `nation_team_id`, `nation_position`.

# %%
#df[df.nation_team_id.isnull()]

# %%
#df[df.nation_position.isnull()]

# %% [markdown]
# `Takeaways:`
# - Number of Nulls missing is greater than %90 so we will be eliminating these columns.

# %% [markdown]
# ***

# %% [markdown]
# # `pace`, `shooting`,`dribbling`, `passing`, `defending`, `physic`.

# %%
#df[df.pace.isnull()]

# %%
#df[df.shooting.isnull()]

# %%
#df[df.passing.isnull()]

# %%
#df[df.dribbling.isnull()]

# %%
#df[df.defending.isnull()]

# %%
#df[df.physic.isnull()]

# %% [markdown]
# `Takeaways:`
# - Most of these null values are for goal keepers and can be replaced with 0 because these skills are not a requirement for their career field.

# %% [markdown]
# ***

# %% [markdown]
# # Import [Prepare.py](https://github.com/Jules-Ray-Kayla-Bert-Capstone-FiFA/fifa/blob/main/prepare.py) File.
# `Summary:`
#     This file was created with the purpose of cleaning, encoding, scaling, dropping, and adding collumns to our existing data. It is necessary to complete this preperation step before we start exploring and modeling our data.

# %%
#defining df as our imported prepped data.
df = prepare.prepped_data(df)
df
# Out:
# Before dropping nulls, 142079 rows, 111 cols
# After dropping nulls. 131489 rows. 66 cols
# After clening the data and adding encoded columns. 98804 rows. 82 cols
#        sofifa_id      short_name player_positions  overall  potential  \
# 0         158023        L. Messi       RW, ST, CF       93         93
# 1         190871       Neymar Jr          LW, CAM       91         91
# 2         231747       K. Mbappé           ST, LW       91         95
# 3         230621   G. Donnarumma               GK       89         93
# 4         155862    Sergio Ramos               CB       88         88
# ...          ...             ...              ...      ...        ...
# 98799     234292    L. Järvenpää               RB       57         70
# 98800     234294      L. Lingman               RW       57         72
# 98801     234297    S. Dahlström               CM       57         72
# 98802     234300  L. Lappalainen               ST       57         76
# ...

# %% [markdown]
# # Speperating Goalkeepers, Forwards, & Midfielders

# %%
##############- reserve and substitute -##########
# Reserved and substitue players
df_reserve = df[df.club_position == 'RES']
df_substitute = df[df.club_position == 'SUB']

################- Goal Keepers -###############
#GK
active_goalkeepers = df[(df.club_position == 'GK')]
# Reserved Goalkeepers
df_reserve_goalkeepers = df_reserve[df_reserve.player_positions == 'GK']
#substitute Goalkeepers
df_substitute_goalkeepers = df_substitute[df_substitute.player_positions == 'GK']

################- forwards - ##################
#ST, RS, LS, LW, RW, LF, CF
active_forwards = df[(df.club_position == 'ST') | (df.club_position == 'RS') | (df.club_position == 'LS') | (df.club_position == 'LW') | (df.club_position == 'RW') | (df.club_position == 'LF') | (df.club_position == 'CF')]
# Reserved fowards
#ST, RS, LS, LW, RW, LF, CF
df_reserve_forwards = df_reserve[(df_reserve.player_positions == 'ST')          | (df_reserve.player_positions == 'RW') |
                                 (df_reserve.player_positions == 'ST, CAM')     | (df_reserve.player_positions == 'LW') |
                                 (df_reserve.player_positions == 'RW, LW')      | (df_reserve.player_positions == 'LW, ST') |
                                 (df_reserve.player_positions == 'ST, RW')      | (df_reserve.player_positions == 'ST, CF') |
                                 (df_reserve.player_positions == 'ST, LM')      | (df_reserve.player_positions == 'ST, RM') |
                                 (df_reserve.player_positions == 'RW, ST')      | (df_reserve.player_positions == 'ST, LW') |
                                 (df_reserve.player_positions == 'RW, RM')      | (df_reserve.player_positions == 'LW, CAM') |
                                 (df_reserve.player_positions == 'LW, RW')      | (df_reserve.player_positions == 'RW, CM') |
                                 (df_reserve.player_positions == 'RW, LW, CAM') | (df_reserve.player_positions == 'ST, RW, LW') |
                                 (df_reserve.player_positions == 'LW, LM')      | (df_reserve.player_positions == 'CF') |
                                 (df_reserve.player_positions == 'RW, CAM')     | (df_reserve.player_positions == 'ST, LW, RW') |
                                 (df_reserve.player_positions == 'CF, ST, CAM') | (df_reserve.player_positions == 'LW, LB') |
                                 (df_reserve.player_positions == 'CF, RM, ST')  | (df_reserve.player_positions == 'LW, LM, LB') |
                                 (df_reserve.player_positions == 'CF, ST')      | (df_reserve.player_positions == 'RW, CAM, ST') |
                                 (df_reserve.player_positions == 'ST, RM, LM')  | (df_reserve.player_positions == 'LW, RW, CAM') |
                                 (df_reserve.player_positions == 'ST, LW, LM')  | (df_reserve.player_positions == 'LW, CF, CAM') |
                                 (df_reserve.player_positions == 'CF, CAM, ST') | (df_reserve.player_positions == 'LW, CF, RW') |
                                 (df_reserve.player_positions == 'LW, RW, ST')  | (df_reserve.player_positions == 'RW, LW, ST') |
                                 (df_reserve.player_positions == 'CF, CAM, LM') | (df_reserve.player_positions == 'ST, LM, LW') |
                                 (df_reserve.player_positions == 'RW, LW, CF')  | (df_reserve.player_positions == 'LW, CAM, RW') |
                                 (df_reserve.player_positions == 'RW, ST, LM')  | (df_reserve.player_positions == 'RW, ST, LW') |
                                 (df_reserve.player_positions == 'CF, LM')      | (df_reserve.player_positions == 'ST, LM, RM') |
                                 (df_reserve.player_positions == 'RW, RM, RB')  | (df_reserve.player_positions == 'ST, CAM, RM') |
                                 (df_reserve.player_positions == 'RW, LW, LM')  | (df_reserve.player_positions == 'RW, RM, LM') |
                                 (df_reserve.player_positions == 'RW, LW, RM')]
# Substitute forwards
#ST, RS, LS, LW, RW, LF, CF
df_substitute_forwards = df_substitute[(df_substitute.player_positions == 'ST')    | (df_substitute.player_positions == 'RW') |
                                 (df_substitute.player_positions == 'ST, CAM')     | (df_substitute.player_positions == 'LW') |
                                 (df_substitute.player_positions == 'RW, LW')      | (df_substitute.player_positions == 'LW, ST') |
                                 (df_substitute.player_positions == 'ST, RW')      | (df_substitute.player_positions == 'ST, CF') |
                                 (df_substitute.player_positions == 'ST, LM')      | (df_substitute.player_positions == 'ST, RM') |
                                 (df_substitute.player_positions == 'RW, ST')      | (df_substitute.player_positions == 'ST, LW') |
                                 (df_substitute.player_positions == 'RW, RM')      | (df_substitute.player_positions == 'LW, CAM') |
                                 (df_substitute.player_positions == 'LW, RW')      | (df_substitute.player_positions == 'RW, CM') |
                                 (df_substitute.player_positions == 'RW, LW, CAM') | (df_substitute.player_positions == 'ST, RW, LW') |
                                 (df_substitute.player_positions == 'LW, LM')      | (df_substitute.player_positions == 'CF') |
                                 (df_substitute.player_positions == 'RW, CAM')     | (df_substitute.player_positions == 'ST, LW, RW') |
                                 (df_substitute.player_positions == 'CF, ST, CAM') | (df_substitute.player_positions == 'LW, LB') |
                                 (df_substitute.player_positions == 'CF, RM, ST')  | (df_substitute.player_positions == 'LW, LM, LB') |
                                 (df_substitute.player_positions == 'CF, ST')      | (df_substitute.player_positions == 'RW, CAM, ST') |
                                 (df_substitute.player_positions == 'ST, RM, LM')  | (df_substitute.player_positions == 'LW, RW, CAM') |
                                 (df_substitute.player_positions == 'ST, LW, LM')  | (df_substitute.player_positions == 'LW, CF, CAM') |
                                 (df_substitute.player_positions == 'CF, CAM, ST') | (df_substitute.player_positions == 'LW, CF, RW') |
                                 (df_substitute.player_positions == 'LW, RW, ST')  | (df_substitute.player_positions == 'RW, LW, ST') |
                                 (df_substitute.player_positions == 'CF, CAM, LM') | (df_substitute.player_positions == 'ST, LM, LW') |
                                 (df_substitute.player_positions == 'RW, LW, CF')  | (df_substitute.player_positions == 'LW, CAM, RW') |
                                 (df_substitute.player_positions == 'RW, ST, LM')  | (df_substitute.player_positions == 'RW, ST, LW') |
                                 (df_substitute.player_positions == 'CF, LM')      | (df_substitute.player_positions == 'ST, LM, RM') |
                                 (df_substitute.player_positions == 'RW, RM, RB')  | (df_substitute.player_positions == 'ST, CAM, RM') |
                                 (df_substitute.player_positions == 'RW, LW, LM')  | (df_substitute.player_positions == 'RW, RM, LM') |
                                 (df_substitute.player_positions == 'RW, LW, RM')]

###################- defenders -######################
#RCB, LCB, LB, RB, CB, RWB, LWB
defenders = df[(df.club_position == 'RCB') | (df.club_position == 'LCB') | (df.club_position == 'LB') | (df.club_position == 'RB') | (df.club_position == 'CB') | (df.club_position == 'RWB') | (df.club_position == 'LWB')]

df_substitute_defenders =  df_substitute[(df_substitute.player_positions == 'CB') | (df_substitute.player_positions == 'LB') |
                                         (df_substitute.player_positions == 'RB') | (df_substitute.player_positions == 'RWB') |
                                         (df_substitute.player_positions == 'LWB')]
df_reserve_defenders =  df_reserve[(df_reserve.player_positions == 'CB') | (df_reserve.player_positions == 'LB') |
                                   (df_reserve.player_positions == 'RB') | (df_reserve.player_positions == 'RWB') |
                                   (df_reserve.player_positions == 'LWB')]


################- Midfielders -########################
#LCM, RCM, RM, LM, CAM, LDM, RDM, CDM, LAM, RAM 
midfielders = df[(df.club_position == 'LCM') | (df.club_position == 'RCM') | (df.club_position == 'RM') | (df.club_position == 'LM') | (df.club_position == 'CAM') | (df.club_position == 'LDM') | (df.club_position == 'RDM') | (df.club_position == 'CDM') | (df.club_position == 'LAM') | (df.club_position == 'RAM')] 
#LCM, RCM, RM, LM, CAM, LDM, RDM, CDM, LAM, RAM 
df_reserve_midfielders = df_reserve[(df_reserve.player_positions == 'CM')           | (df_reserve.player_positions == 'CDM, CM')|
                                    (df_reserve.player_positions == 'CAM')          | (df_reserve.player_positions == 'CM, CDM')|
                                    (df_reserve.player_positions == 'CDM')          | (df_reserve.player_positions == 'LM')|
                                    (df_reserve.player_positions == 'RM')           | (df_reserve.player_positions == 'CAM, CM')| 
                                    (df_reserve.player_positions == 'CM, CAM')      | (df_reserve.player_positions == 'RM, LM')| 
                                    (df_reserve.player_positions == 'LM, RM')       | (df_reserve.player_positions == 'CDM, CB')| 
                                    (df_reserve.player_positions == 'RM, ST')       | (df_reserve.player_positions == 'CAM, ST')| 
                                    (df_reserve.player_positions == 'LM, LW')       | (df_reserve.player_positions == 'RM, CAM')| 
                                    (df_reserve.player_positions == 'CM, CDM, CAM') | (df_reserve.player_positions == 'LM, CAM')|
                                    (df_reserve.player_positions == 'CAM, RM')      | (df_reserve.player_positions == 'LM, RM, CAM') |
                                    (df_reserve.player_positions == 'LM, CF')       | (df_reserve.player_positions == 'CAM, LW') |
                                    (df_reserve.player_positions == 'LM, ST')       | (df_reserve.player_positions == 'CAM, CM, LM') |
                                    (df_reserve.player_positions == 'RM, CM')       | (df_reserve.player_positions == 'RM, LM, CM') |
                                    (df_reserve.player_positions == 'RM, RWB')      | (df_reserve.player_positions == 'CAM, RM, LM') |
                                    (df_reserve.player_positions == 'CAM, CDM')     | (df_reserve.player_positions == 'CAM, LM') |
                                    (df_reserve.player_positions == 'RM, LM, CAM')  | (df_reserve.player_positions == 'CM, CAM, RM') |
                                    (df_reserve.player_positions == 'CDM, CM, CB')  | (df_reserve.player_positions == 'CAM, CF') |
                                    (df_reserve.player_positions == 'CM, CAM, CDM') | (df_reserve.player_positions == 'CM, RM') |
                                    (df_reserve.player_positions == 'CAM, RW, LW')  | (df_reserve.player_positions == 'LM, CAM, RM') |
                                    (df_reserve.player_positions == 'CDM, RB')      | (df_reserve.player_positions == 'RM, LM, ST') |
                                    (df_reserve.player_positions == 'LM, RM, CF')   | (df_reserve.player_positions == 'CAM, LM, RM') |
                                    (df_reserve.player_positions == 'CM, CB')       | (df_reserve.player_positions == 'RM, ST, RB') |
                                    (df_reserve.player_positions == 'CDM, CB, CM')  | (df_reserve.player_positions == 'LM, ST, RM') |
                                    (df_reserve.player_positions == 'RM, CF')       | (df_reserve.player_positions == 'LM, CAM, CM') |
                                    (df_reserve.player_positions == 'CAM, CF, RW')  | (df_reserve.player_positions == 'LM, LW, RW') |
                                    (df_reserve.player_positions == 'CM, RW')       | (df_reserve.player_positions == 'RM, RW') |
                                    (df_reserve.player_positions == 'CM, RM, LM')   | (df_reserve.player_positions == 'RM, ST, LB') |
                                    (df_reserve.player_positions == 'CM, CAM, RW')  | (df_reserve.player_positions == 'CAM, CM, RM') | 
                                    (df_reserve.player_positions == 'CAM, CM, CF')  | (df_reserve.player_positions == 'CDM, LB, LM') |
                                    (df_reserve.player_positions == 'LM, ST, LB')   | (df_reserve.player_positions == 'RM, LWB') |
                                    (df_reserve.player_positions == 'LM, CDM')      | (df_reserve.player_positions == 'CM, LM, RM') |
                                    (df_reserve.player_positions == 'CAM, CM, ST')  | (df_reserve.player_positions == 'RM, CM, LM') |
                                    (df_reserve.player_positions == 'CAM, RM, RW')  | (df_reserve.player_positions == 'CDM, CM, CAM') |
                                    (df_reserve.player_positions == 'CDM, CM, RM')  | (df_reserve.player_positions == 'CAM, ST, CM') |
                                    (df_reserve.player_positions == 'RM, RB')       | (df_reserve.player_positions == 'CM, RM, CAM') | 
                                    (df_reserve.player_positions == 'RM, CAM, CM')  | (df_reserve.player_positions == 'CAM, RW') |
                                    (df_reserve.player_positions == 'CM, CF, LM')   | (df_reserve.player_positions == 'RM, RB, RWB') |
                                    (df_reserve.player_positions == 'CDM, LB, CB')  | (df_reserve.player_positions == 'LM, LWB, LB') |
                                    (df_reserve.player_positions == 'CAM, RM, CM')  | (df_reserve.player_positions == 'CDM, RB, RWB') |
                                    (df_reserve.player_positions == 'CM, RB')       | (df_reserve.player_positions == 'CM, CDM, RB') |
                                    (df_reserve.player_positions == 'RM, LM, RW')   | (df_reserve.player_positions == 'RM, LW') |
                                    (df_reserve.player_positions == 'CDM, CAM, CM') | (df_reserve.player_positions == 'LM, RM, LWB') | 
                                    (df_reserve.player_positions == 'RM, RWB, RB')  | (df_reserve.player_positions == 'CAM, ST, RW') | 
                                    (df_reserve.player_positions == 'LM, CM')       | (df_reserve.player_positions == 'LM, ST, CAM') | 
                                    (df_reserve.player_positions == 'CM, CDM, LWB') | (df_reserve.player_positions == 'LM, CAM, ST') | 
                                    (df_reserve.player_positions == 'CDM, CB, RM')  | (df_reserve.player_positions == 'CDM, CM, RB') | 
                                    (df_reserve.player_positions == 'CM, LB')       | (df_reserve.player_positions == 'CAM, LW, LM') | 
                                    (df_reserve.player_positions == 'CAM, CM, LW')  | (df_reserve.player_positions == 'CDM, RB, LB') |
                                    (df_reserve.player_positions == 'LM, RM, LB')   | (df_reserve.player_positions == 'LM, LB, RM') |
                                    (df_reserve.player_positions == 'RM, ST, CAM')  | (df_reserve.player_positions == 'CAM, LM, LW') | 
                                    (df_reserve.player_positions == 'CM, LW')       | (df_reserve.player_positions == 'RM, RB, RW') | 
                                    (df_reserve.player_positions == 'CM, CDM, RM')  | (df_reserve.player_positions == 'CM, LM') |
                                    (df_reserve.player_positions == 'LM, LB')]

df_substitute_midfielders = df_substitute[(df_substitute.player_positions == 'CM')           | (df_substitute.player_positions == 'CDM, CM')|
                                      (df_substitute.player_positions == 'CAM')           | (df_substitute.player_positions == 'CM, CDM')|
                                      (df_substitute.player_positions == 'CDM')           | (df_substitute.player_positions == 'LM')|
                                      (df_substitute.player_positions == 'RM')            | (df_substitute.player_positions == 'CAM, CM')| 
                                      (df_substitute.player_positions == 'CM, CAM')       | (df_substitute.player_positions == 'RM, LM')| 
                                      (df_substitute.player_positions == 'LM, RM')        | (df_substitute.player_positions == 'CDM, CB')| 
                                      (df_substitute.player_positions == 'RM, ST')        | (df_substitute.player_positions == 'CAM, ST')| 
                                      (df_substitute.player_positions == 'LM, LW')        | (df_substitute.player_positions == 'RM, CAM')| 
                                      (df_substitute.player_positions == 'CM, CDM, CAM')  | (df_substitute.player_positions == 'LM, CAM')|
                                      (df_substitute.player_positions == 'CAM, RM')       | (df_substitute.player_positions == 'LM, RM, CAM') |
                                      (df_substitute.player_positions == 'LM, CF')        | (df_substitute.player_positions == 'CAM, LW') |
                                      (df_substitute.player_positions == 'LM, ST')        | (df_substitute.player_positions == 'CAM, CM, LM') |
                                      (df_substitute.player_positions == 'RM, CM')        | (df_substitute.player_positions == 'RM, LM, CM') |
                                      (df_substitute.player_positions == 'RM, RWB')       | (df_substitute.player_positions == 'CAM, RM, LM') |
                                      (df_substitute.player_positions == 'CAM, CDM')      | (df_substitute.player_positions == 'CAM, LM') |
                                      (df_substitute.player_positions == 'RM, LM, CAM')   | (df_substitute.player_positions == 'CM, CAM, RM') |
                                      (df_substitute.player_positions == 'CDM, CM, CB')   | (df_substitute.player_positions == 'CAM, CF') |
                                      (df_substitute.player_positions == 'CM, CAM, CDM')  | (df_substitute.player_positions == 'CM, RM') |
                                      (df_substitute.player_positions == 'CAM, RW, LW')   | (df_substitute.player_positions == 'LM, CAM, RM') |
                                      (df_substitute.player_positions == 'CDM, RB')       | (df_substitute.player_positions == 'RM, LM, ST') |
                                      (df_substitute.player_positions == 'LM, RM, CF')    | (df_substitute.player_positions == 'CAM, LM, RM') |
                                      (df_substitute.player_positions == 'CM, CB')        | (df_substitute.player_positions == 'RM, ST, RB') |
                                      (df_substitute.player_positions == 'CDM, CB, CM')   | (df_substitute.player_positions == 'LM, ST, RM') |
                                      (df_substitute.player_positions == 'RM, CF')        | (df_substitute.player_positions == 'LM, CAM, CM') |
                                      (df_substitute.player_positions == 'CAM, CF, RW')   | (df_substitute.player_positions == 'LM, LW, RW') |
                                      (df_substitute.player_positions == 'CM, RW')        | (df_substitute.player_positions == 'RM, RW') |
                                      (df_substitute.player_positions == 'CM, RM, LM')    | (df_substitute.player_positions == 'RM, ST, LB') |
                                      (df_substitute.player_positions == 'CM, CAM, RW')   | (df_substitute.player_positions == 'CAM, CM, RM') | 
                                      (df_substitute.player_positions == 'CAM, CM, CF')   | (df_substitute.player_positions == 'CDM, LB, LM') |
                                      (df_substitute.player_positions == 'LM, ST, LB')    | (df_substitute.player_positions == 'RM, LWB') |
                                      (df_substitute.player_positions == 'LM, CDM')       | (df_substitute.player_positions == 'CM, LM, RM') |
                                      (df_substitute.player_positions == 'CAM, CM, ST')   | (df_substitute.player_positions == 'RM, CM, LM') |
                                      (df_substitute.player_positions == 'CAM, RM, RW')   | (df_substitute.player_positions == 'CDM, CM, CAM') |
                                      (df_substitute.player_positions == 'CDM, CM, RM')   | (df_substitute.player_positions == 'CAM, ST, CM') |
                                      (df_substitute.player_positions == 'RM, RB')        | (df_substitute.player_positions == 'CM, RM, CAM') | 
                                      (df_substitute.player_positions == 'RM, CAM, CM')   | (df_substitute.player_positions == 'CAM, RW') |
                                      (df_substitute.player_positions == 'CM, CF, LM')    | (df_substitute.player_positions == 'RM, RB, RWB') |
                                      (df_substitute.player_positions == 'CDM, LB, CB')   | (df_substitute.player_positions == 'LM, LWB, LB') |
                                      (df_substitute.player_positions == 'CAM, RM, CM')   | (df_substitute.player_positions == 'CDM, RB, RWB') |
                                      (df_substitute.player_positions == 'CM, RB')        | (df_substitute.player_positions == 'CM, CDM, RB') |
                                      (df_substitute.player_positions == 'RM, LM, RW')    | (df_substitute.player_positions == 'RM, LW') |
                                      (df_substitute.player_positions == 'CDM, CAM, CM')  | (df_substitute.player_positions == 'LM, RM, LWB') | 
                                      (df_substitute.player_positions == 'RM, RWB, RB')   | (df_substitute.player_positions == 'CAM, ST, RW') | 
                                      (df_substitute.player_positions == 'LM, CM')        | (df_substitute.player_positions == 'LM, ST, CAM') | 
                                      (df_substitute.player_positions == 'CM, CDM, LWB')  | (df_substitute.player_positions == 'LM, CAM, ST') | 
                                      (df_substitute.player_positions == 'CDM, CB, RM')   | (df_substitute.player_positions == 'CDM, CM, RB') | 
                                      (df_substitute.player_positions == 'CM, LB')        | (df_substitute.player_positions == 'CAM, LW, LM') | 
                                      (df_substitute.player_positions == 'CAM, CM, LW')   | (df_substitute.player_positions == 'CDM, RB, LB') |
                                      (df_substitute.player_positions == 'LM, RM, LB')    | (df_substitute.player_positions == 'LM, LB, RM') |
                                      (df_substitute.player_positions == 'RM, ST, CAM')   | (df_substitute.player_positions == 'CAM, LM, LW') | 
                                      (df_substitute.player_positions == 'CM, LW')        | (df_substitute.player_positions == 'RM, RB, RW') | 
                                      (df_substitute.player_positions == 'CM, CDM, RM')   | (df_substitute.player_positions == 'CM, LM') |
                                      (df_substitute.player_positions == 'LM, LB')]

# %%
print("total active Goal keepers:",active_goalkeepers.value_counts().sum())
print("total reserved Goal keepers:",df_reserve_goalkeepers.value_counts().sum())
print("total substitute Goal keepers:",df_substitute_goalkeepers.value_counts().sum())
print("total Goalkeeper count:",df[(df.player_positions == 'GK')].value_counts().sum())
print("-------------------------------------")
# Out:
# total active Goal keepers: 3661
# total reserved Goal keepers: 2424
# total substitute Goal keepers: 5281
# total Goalkeeper count: 11366

# %%
print("total active forward players :", forwards.value_counts().sum())
print("total reserve forward players :", df_reserve_forwards.value_counts().sum())
print("total substitute forward players :", df_substitute_forwards.value_counts().sum())
print("total number of forward players: ", 6404 + 3050 + 8020)
print("-------------------------------------")
# Out:
# total active forward players : 6404
# total reserve forward players : 3050
# total substitute forward players : 8020
# total number of forward players:  17474

# %%
print("total active midfielders players :", midfielders.value_counts().sum())
print("total reserve midfielders players :", df_reserve_midfielders.value_counts().sum())
print("total substitute midfielders players :", df_substitute_midfielders.value_counts().sum())
print("total number of midfielders players: ", 14650 + 5883 + 13857)
print("-------------------------------------")
# Out:
# total active midfielders players : 14650
# total reserve midfielders players : 5883
# total substitute midfielders players : 13857
# total number of midfielders players:  34390

# %% [markdown]
# # `Explore`

# %% [markdown]
# ## Importing split function to start our exploring on our train data.

# %%
#dropping goal keepers
df = df[df.player_positions != 'GK']
df

# %%
df.year.describe()

# %%
y1 = df[(df.year == 2015)]
y2 = df[(df.year == 2016)]
y3 = df[(df.year == 2017)]
y4 = df[(df.year == 2018)]
y5 = df[(df.year == 2019)]
y6 = df[(df.year == 2020)]
y7 = df[(df.year == 2021)]
y8 = df[(df.year == 2022)]

# %%
train = pd.concat([y1,y2,y3,y4,y5])
validate = pd.concat([y6,y7])
test = pd.concat([y8])

# %%
train

# %% [markdown]
# ***
# # Relationship to Wage_euro Plot

# %%
plt.figure(figsize = (12,8))
train.corr()['wage_eur'].sort_values(ascending=False).plot(kind='barh', color='orange')
plt.title('Relationship with wages')
plt.xlabel('Relationship')
plt.ylabel('Features')
plt.show()

# %%
features_cor =  train.corr()['wage_eur'].sort_values(ascending=False)
features_cor = pd.DataFrame(features_cor)
features_cor.tail(58)

# %% [markdown]
# ## Questions to explore?

# %% [markdown]
# `Does age impact salary?`
#
# `Does seniority(length of time playing with a club) impact salary?`
#
# `Does the club you start with impact your salary?`
#
# `Do players with unusual body types have higher or lower salaries?`
#
# `Does nationality impact salary?`
#
# `Does international reputation impact salary?`
#
# `Does contract length positively or negatively impact salary?`
#
# `Overarching question: What features are most important in player salaries?`
#
# - Players to focus on for Eriberto Contreras?
# - Additionally I will be focusing on team budgets?

# %%
fig = px.box(train, x="position", y="wage_eur", points="all", animation_frame='year', color="league_name",
                   hover_name="league_name")
fig.update_xaxes(categoryorder = 'mean ascending')
fig.update_layout(title_text='Wages and positions', title_x=0.5)
fig.show()

# %%
fig = px.box(train, x="league_name", y="wage_eur", points="all", animation_frame='year', color="league_name",
                   hover_name="league_name")
fig.update_xaxes(categoryorder = 'mean ascending')
fig.update_layout(title_text='Wage & League', title_x=0.5)
fig.show()

# %%
fig = px.box(train, x="club_name", y="wage_eur", points="all", animation_frame='year', color="league_name",
                   hover_name="league_name")
fig.update_xaxes(categoryorder = 'mean ascending')
fig.update_layout(title_text='Wage & Club', title_x=0.5)
fig.show()

# %%
# df = px.data.gapminder().query("year").query("fifa_total_player_budget")
#train.loc[train['wage_eur'] < 2.6, 'country'] = 'top' # Represent only large countries
fig = px.pie(train, values='wage_eur', names='league_name', title='LEAGUE')
fig.show()

# %%
fig = px.box(train, x="age", y="wage_eur", points="all", animation_frame='year', color="league_name",
                   hover_name="league_name")
fig.update_xaxes(categoryorder = 'mean ascending')
fig.update_layout(title_text='WAGE & AGE', title_x=0.5)
fig.show()

# %%
fig = px.box(train, x="club_joined", y="wage_eur", points="all", animation_frame='year', color="league_name",
                   hover_name="league_name")
fig.update_xaxes(categoryorder = 'mean ascending')
fig.update_layout(title_text='Wage Per Position', title_x=0.5)
fig.show()

# %%
#Does contract length positively or negatively impact salary?

fig = px.box(train, x="club_contract_valid_until", y="wage_eur", points="all", animation_frame='year', color="league_name",
                   hover_name="league_name")
fig.update_xaxes(categoryorder = 'mean ascending')
fig.update_layout(title_text='Wage Per Position and contract ', title_x=0.5)
fig.show()

# %%
# identifying mvp columns
mvp = ['potential', 'reactions', 'vision', 'short_passing','long_passing',
                    'ball_control', 'curve', 'shot_power', 'volleys', 'long_shots',
                    'fk_accuracy', 'crossing', 'skill_dribbling']

# %%
X_train = train[mvp]
y_train = train['wage_eur']

X_validate = validate[mvp]
y_validate = validate['wage_eur']

X_test = test[mvp]
y_test = test['wage_eur']

# %% [markdown]
# # Scaling

# %%
scaler = RobustScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_validate_scaled = scaler.transform(X_validate)
X_test_scaled = scaler.transform(X_test)

# %%
#scaler, X_train_scaled, X_validate_scaled, X_test_scaled = scale_data(X_train, X_validate, X_test, return_scaler=True)

# %% [markdown]
# # RMSE

# %%
# We need y_train and y_validate to be dataframes to append the new columns with predicted values.
y_train = pd.DataFrame(y_train)
y_validate = pd.DataFrame(y_validate)
# 1. Predict price_pred_mean
wage_eur_pred_mean = y_train.wage_eur.mean()
# creating a wage_eur_pred_mean column for my y_train
y_train['wage_eur_pred_mean'] = y_train.wage_eur.mean()
# creating a wage_eur_pred_mean column for my y_validate
y_validate['wage_eur_pred_mean'] = y_validate.wage_eur.mean()
# 2. compute price_pred_median
# creating a predictive median for y train 
y_train['wage_eur_pred_median'] = y_train.wage_eur.median()
# creating a predictive median for y_validate
y_validate['wage_eur_pred_median'] = y_validate.wage_eur.median()
# 3. RMSE of price_pred_mean
rmse_train = mean_squared_error(y_train.wage_eur, y_train.wage_eur_pred_mean)**(1/2)
rmse_validate = mean_squared_error(y_validate.wage_eur, y_validate.wage_eur_pred_mean)**(1/2)
print("RMSE using Mean\nTrain/In-Sample: ", round(rmse_train, 2),
      "\nValidate/Out-of-Sample: ", round(rmse_validate, 2))
# 4. RMSE of wage_eur_pred_median
rmse_train = mean_squared_error(y_train.wage_eur, y_train.wage_eur_pred_median)**(1/2)
rmse_validate = mean_squared_error(y_validate.wage_eur, y_validate.wage_eur_pred_median)**(1/2)
print("RMSE using Median\nTrain/In-Sample: ", round(rmse_train, 2),
      "\nValidate/Out-of-Sample: ", round(rmse_validate, 2))

# %%
y_test = pd.DataFrame(y_test)

y_test

# %%
# create the model object
lm = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lm.fit(X_train_scaled, y_train.wage_eur)

# predict train
y_train['wage_eur_pred_lm'] = lm.predict(X_train_scaled)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.wage_eur, y_train.wage_eur_pred_lm)**(1/2)

# predict validate
y_validate['wage_eur_pred_lm'] = lm.predict(X_validate_scaled)

# evaluate: rmse
rmse_validate_lm = mean_squared_error(y_validate.wage_eur, y_validate.wage_eur_pred_lm)**(1/2)

print("RMSE for OLS using LinearRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate_lm)

# %%
#residuals
y_train['lm_residuals'] = y_train['wage_eur_pred_lm'] - y_train['wage_eur']
y_validate['lm_residuals'] = y_validate['wage_eur_pred_lm'] - y_validate['wage_eur']

# %% [markdown]
# # LassoLars(lars)

# %%
# create the model object
lars = LassoLars(alpha=1.0)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lars.fit(X_train_scaled, y_train.wage_eur)

# predict train
y_train['wage_eur_pred_lars'] = lars.predict(X_train_scaled)

# evaluate: rmse
rmse_train_lars = mean_squared_error(y_train.wage_eur, y_train.wage_eur_pred_lars)**(1/2)

# predict validate
y_validate['wage_eur_pred_lars'] = lars.predict(X_validate_scaled)

# evaluate: rmse
rmse_validate_lars = mean_squared_error(y_validate.wage_eur, y_validate.wage_eur_pred_lars)**(1/2)

print("RMSE for Lasso + Lars\nTraining/In-Sample: ", rmse_train_lars, 
      "\nValidation/Out-of-Sample: ", rmse_validate_lars)

# %%
#residuals
y_train['lars_residuals'] = y_train['wage_eur_pred_lars'] - y_train['wage_eur']
y_validate['lars_residuals'] = y_validate['wage_eur_pred_lars'] - y_validate['wage_eur']

# %% [markdown]
# # Twedie Regression Model (GLM)

# %%
# create the model object
glm = TweedieRegressor(power=1, alpha=0)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
glm.fit(X_train_scaled, y_train.wage_eur)

# predict train
y_train['wage_eur_pred_glm'] = glm.predict(X_train_scaled)

# evaluate: rmse
rmse_train_glm = mean_squared_error(y_train.wage_eur, y_train.wage_eur_pred_glm)**(1/2)

# predict validate
y_validate['wage_eur_pred_glm'] = glm.predict(X_validate_scaled)

# evaluate: rmse
rmse_validate_glm = mean_squared_error(y_validate.wage_eur, y_validate.wage_eur_pred_glm)**(1/2)

print("RMSE for GLM using Tweedie, power=1 & alpha=0\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate_glm)

# %%
#residuals
y_train['glm_residuals'] = y_train['wage_eur_pred_glm'] - y_train['wage_eur']
y_validate['glm_residuals'] = y_validate['wage_eur_pred_glm'] - y_validate['wage_eur']

# %% [markdown]
# # Polynomial Regression

# %%
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled
X_train_degree2 = pf.fit_transform(X_train_scaled)

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate_scaled)
X_test_degree2 = pf.transform(X_test_scaled)

# %%
# create the model object
lm2 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lm2.fit(X_train_degree2, y_train.wage_eur)

# predict train
y_train['wage_eur_pred_lm2'] = lm2.predict(X_train_degree2)

# evaluate: rmse
rmse_train_lm2 = mean_squared_error(y_train.wage_eur, y_train.wage_eur_pred_lm2)**(1/2)

# predict validate
y_validate['wage_eur_pred_lm2'] = lm2.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate_lm2 = mean_squared_error(y_validate.wage_eur, y_validate.wage_eur_pred_lm2)**(1/2)

print("RMSE for Polynomial Model, degrees=2\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)

# %%
#residuals
y_train['poly_residuals'] = y_train['wage_eur_pred_lm2'] - y_train['wage_eur']
y_validate['poly_residuals'] = y_validate['wage_eur_pred_lm2'] - y_validate['wage_eur']

# %% [markdown]
# # Evaluating Models

# %%
from sklearn.linear_model import LinearRegression
y = pd.DataFrame(y_train.wage_eur)
X = pd.DataFrame(X_train_scaled)
# assuming X and y are already defined
model = LinearRegression().fit(X, y)
train['yhat'] = model.predict(X)
train

# %%
df = pd.DataFrame(train[['potential', 'reactions', 'vision', 'short_passing','long_passing',
       'ball_control','wage_eur','yhat']])
df.head()

# %%
#creating a baseline from the mean of the target variable
baseline = y.mean()
df['baseline'] = y.wage_eur.mean()
# turning baseline to int from float
df.baseline = df.baseline.astype(int)
# residual = actual - predicted
df['residual'] = df.wage_eur - df.yhat
df['baseline_residual'] = df.wage_eur - df.baseline

# %%
baseline

# %%
df['residual^2'] = df.residual**2
df['baseline_residual^2'] = df.baseline_residual**2

df.head()

# %%
SSE = df['residual^2'].sum()
SSE_baseline = df['baseline_residual^2'].sum()

print('SSE =', "{:.1f}".format(SSE))
print("SSE Baseline =", "{:.1f}".format(SSE_baseline))

if SSE < SSE_baseline:
    print('SSE is better than baseline')
else:
    print('baseline is better')

# %%
MSE = SSE/len(df)
MSE_baseline = SSE_baseline/len(df)

print("MSE = ", "{:.1f}".format(MSE))
print("MSE baseline = ", "{:.1f}".format(MSE_baseline))

if MSE < MSE_baseline:
    print('MSE is better than baseline')
else:
    print('baseline is better')

# %%
from math import sqrt
RMSE = sqrt(MSE)
RMSE_baseline =  sqrt(MSE_baseline)

if RMSE < RMSE_baseline:
    print('RMSE is better than baseline')
else:
    print('baseline is better')
    
print("RMSE = ", "{:.1f}".format(RMSE))
print("RMSE baseline = ", "{:.1f}".format(RMSE_baseline))

# %%
if SSE < SSE_baseline:
    print('OLS regression model performs better than the baseline')
else:
    print('OLS regression model performs worse than the baseline')

# %%
# sklearn.metrics.explained_variance_score
from sklearn.metrics import explained_variance_score
evs = explained_variance_score(df.wage_eur, df.yhat)
print('Explained Variance = ', round(evs,3))

# %%
# calculate R2 the easy way:
from sklearn.metrics import r2_score
r2_score(df.wage_eur, df.yhat)

# %%
import statsmodels.api as sm
X2 = sm.add_constant(df.potential)
est = sm.OLS(df.wage_eur, X2)
est2 = est.fit()
print(est2.summary())

# %%
def residuals(actual, predicted):
    return actual - predicted

#sum of squared errors (SSE)
def sse(actual, predicted):
    return (residuals(actual, predicted) **2).sum()

#explained sum of squares (ESS)
def ess(actual, predicted):
    return ((predicted - actual.mean()) ** 2).sum()

#total sum of squares (TSS)
def tss(actual):
    return ((actual - actual.mean()) ** 2).sum()

#mean squared error (MSE)
def mse(actual, predicted):
    n = actual.shape[0]
    return sse(actual, predicted) / n

#root mean squared error (RMSE)
def rmse(actual, predicted):
    return math.sqrt(mse(actual, predicted))

# returns r2 scor
def r2_score(actual, predicted):
    return ess(actual, predicted) / tss(actual)

def regression_errors(actual, predicted):
    return pd.Series({
                        'SSE': sse(actual, predicted),
                        'ESS': ess(actual, predicted),
                        'TSS': tss(actual),
                        'MSE': mse(actual, predicted),
                        'RMSE': rmse(actual, predicted),
                        })

def baseline_mean_errors(actual):
    predicted = actual.mean()
    return {
             'SSE': sse(actual, predicted),
             'MSE': mse(actual, predicted),
             'RMSE': rmse(actual, predicted),
            }

def better_than_baseline(actual, predicted):
    rmse_baseline = rmse(actual, actual.mean())
    rmse_model = rmse(actual, predicted)
    return rmse_model < rmse_baseline

# %%
actual = y_train.wage_eur
predicted = df.yhat
residuals = actual - predicted

# %%
def actual_vs_predicted():
    # plot to visualize actual vs predicted. 
    plt.figure(figsize=(16,8))
    plt.hist(y_validate.wage_eur, color='blue', alpha=.5, label="Actual Final wage_eur")
    plt.hist(y_validate.wage_eur_pred_lm, color='red', alpha=.5, label="Model: LinearRegression")
    plt.hist(y_validate.wage_eur_pred_glm, color='yellow', alpha=.5, label="Model: TweedieRegressor")
    plt.hist(y_validate.wage_eur_pred_lm2, color='green', alpha=.5, label="Model 2nd degree Polynomial")
    plt.xlabel("Final wage(eur)")
    plt.ylabel("predicted wage_eur")
    plt.title("Comparing the Distribution of Actual wage_eur to Distributions of Predicted wage_eur for the Top Models")
    plt.legend()
    plt.show()
actual_vs_predicted()

# %%
y_train

# %%
metric_df = pd.DataFrame(data=[{
    'model': 'mean_baseline', 
    'RMSE_validate': rmse_validate,
        'r^2_validate': explained_variance_score(y_validate.wage_eur, y_validate.wage_eur_pred_mean)}])
metric_df = metric_df.append({
    'model': 'OLS Regressor', 
    'RMSE_validate': rmse_validate_lm,
    'r^2_validate': explained_variance_score(y_validate.wage_eur, y_validate.wage_eur_pred_lm)}, ignore_index=True)
metric_df = metric_df.append({
    'model': 'Lasso alpha 1', 
    'RMSE_validate': rmse_validate_lars,
    'r^2_validate': explained_variance_score(y_validate.wage_eur, y_validate.wage_eur_pred_lars)}, ignore_index=True)
metric_df = metric_df.append({
    'model': 'GLS (Poisson)', 
    'RMSE_validate': rmse_validate_glm,
    'r^2_validate': explained_variance_score(y_validate.wage_eur, y_validate.wage_eur_pred_glm)}, ignore_index=True)
metric_df = metric_df.append({
    'model': 'Quadratic Model', 
    'RMSE_validate': rmse_validate_lm2,
    'r^2_validate': explained_variance_score(y_validate.wage_eur, y_validate.wage_eur_pred_lm2)}, ignore_index=True)

# %%
metric_df

# %%
y_test = pd.DataFrame(y_test)

# predict on test
y_test['wage_eur_pred_LINEAR'] = lm.predict(X_test_scaled)

# evaluate: rmse
rmse_test_lm = mean_squared_error(y_test.wage_eur, y_test.wage_eur_pred_LINEAR)**(1/2)

print("RMSE for OLS Model using LinearRegression\nOut-of-Sample Performance: ", rmse_test_lm)

y_test = pd.DataFrame(y_test)

# predict on test
y_test['wage_eur_pred_LASSO'] = lars.predict(X_test_scaled)

# evaluate: rmse
rmse_test_lars = mean_squared_error(y_test.wage_eur, y_test.wage_eur_pred_LASSO)**(1/2)

print("RMSE for OLS Model using Lasso\nOut-of-Sample Performance: ", rmse_test_lars)

y_test = pd.DataFrame(y_test)

#predict on test
y_test['pred_Poly'] = lm2.predict(X_test_degree2)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.wage_eur, y_test.pred_Poly)**(0.5)

print(f"""
RMSE for Polynomial Regressor, degrees=2:
Test/Out-of-Sample Performance: {rmse_test}
""")



#predict on test
y_test['wage_eur_pred_glm'] = glm.predict(X_test_scaled)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.wage_eur, y_test.wage_eur_pred_glm)**(1/2)
print("RMSE for GLM using Tweedie, power=1 & alpha=0\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate_glm)

# %%
y_test

# %%
sns.scatterplot(data = y_test)
