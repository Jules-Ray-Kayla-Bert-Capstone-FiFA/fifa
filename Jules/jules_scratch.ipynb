# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import acquire
import prepare

# %%
df = pd.read_excel('fifa_male.xlsx')

# %%
df.head()

# %%
df.shape

# %%
df.isna().sum()

# %%
df.loc[df['short_name'] == 'L. Messi']

# %%
pd.set_option('display.max_columns', 110)

# %%
df.league_level.value_counts()

# %%
#only focus on league level 1.0
df = df.loc[df['league_level'] == 1.0]

# %%
df.shape

# %%
df.isna().sum()

# %%
df.mentality_composure.isna().sum()

# %%
df.goalkeeping_speed.isna().sum()

# %%
df.head()

# %%
df = df.drop(columns = ['player_url', 
                        'long_name', 
                        'dob', 
                        'league_level', 
                        'club_jersey_number', 
                        'club_loaned_from',
                        'nation_jersey_number',
                        'body_type',
                        'real_face',
                        'release_clause_eur',
                        'player_tags', 
                        'player_traits',
                        'mentality_composure',
                        'goalkeeping_speed',
                        'ls', 
                        'st', 
                        'rs', 
                        'lw', 
                        'lf', 
                        'cf', 
                        'rf', 
                        'rw', 
                        'lam', 
                        'cam', 
                        'ram',
                        'lm', 
                        'lcm', 
                        'cm', 
                        'rcm', 
                        'rm', 
                        'lwb', 
                        'ldm', 
                        'cdm', 
                        'rdm', 
                        'rwb', 
                        'lb',
                        'lcb', 
                        'cb', 
                        'rcb', 
                        'rb', 
                        'gk',
                        'player_face_url',
                        'club_logo_url',
                        'club_flag_url',
                        'nation_logo_url',
                        'nation_flag_url'
                       ])

# %%
df.columns.to_list()

# %%
# df = pd.read_excel('fifa_male.xlsx')
# xlsx = pd.ExcelFile('fifa_male.xlsx')
# df1 = pd.read_excel(xlsx, 'FIFA 22')
# df2 = pd.read_excel(xlsx, 'FIFA 21')
# df3 = pd.read_excel(xlsx, 'FIFA 20')
# df4 = pd.read_excel(xlsx, 'FIFA 19')
# df5 = pd.read_excel(xlsx, 'FIFA 18')
# df6 = pd.read_excel(xlsx, 'FIFA 17')
# df7 = pd.read_excel(xlsx, 'FIFA 16')
# df8 = pd.read_excel(xlsx, 'FIFA 15')

# %%
df = acquire.get_fifa_data()

# %%
df.shape

# %%
pd.set_option('display.max_columns', 111)

# %%
df.head()

# %%
df.value_eur.isna().sum()

# %%
# #how to import function from general 

# import sys
 
# # the system path
# sys.path.append('/Users/Ray/codeup-data-science/fifa')
 
# # importing the function
# from acquire import get_fifa_data

# %% [markdown]
# # acquire and prep data

# %%
df = acquire.get_fifa_data()

df = prepare.handle_missing_values(df)
# df = prepare.drop_columns(df)
# df = goal_keeper_stats(df)

# %%
df.club_position.unique()

# %%
df.club_position.nunique()

# %%
#df.loc[df['country'] == 'Taiwan', ['income_level']] = 'HIC'

# %%
pd.set_option('display.max_columns', None)

# %%
#create a column w/ full club position name
df2 = df.copy()

df2['position'] = df.loc[df['club_position'] == 'RW', ['position']] = 'Right Wing'

#ensure it works

df2.loc[df['position'] == 'Right Wing']

# %%
#df['gender_encoded'] = df.gender.map({'Female': 1, 'Male': 0}).astype(int)

# %%
df.head()

# %%
#prep: add position column

df['position'] = df.club_position.map({'RW':'Right Wing',
                                       'ST': 'Striker',
                                       'LW': 'Left Wing',
                                       'RCM': 'Right (off-centre) Centre Midfield',
                                       'GK': 'Goalkeeper',
                                       'CF': 'Centre Forward',
                                       'CDM': 'Centre Defensive Midfield',
                                       'LCB': 'Left Centre Back',
                                       'RDM':'Right Defensive Midfield',
                                       'RS': 'Right Striker',
                                       'LCM':'Left (off-centre) Centre Midfield',
                                       'SUB': 'Substitute',
                                       'CAM': 'Centre Attacking Midfield',
                                       'RCB':'Right Centre Back',
                                       'LDM':'Left Defensive Midfield',
                                       'LB': 'Left Back',
                                       'RB': 'Right Back',
                                       'LM': 'Left Midfield',
                                       'RM': 'Right Midfield',
                                       'CB': 'Centre Back',
                                       'LS': 'Left Striker',
                                       'RES': 'Reserves',
                                       'RWB': 'Right Wing Back',
                                       'LWB': 'Left Wing Back',
                                       'LAM': 'Left Attacking Midfield',
                                       'LF': 'Left Forward',
                                       'RAM': 'Right Attacking Midfield'                                       
                        })

# %%
import prepare2

# %%
df = acquire.get_fifa_data()

df = prepare2.handle_missing_values(df)
# Out:
# Before dropping nulls, 142079 rows, 111 cols
# After dropping nulls. 131874 rows. 64 cols
# After feature engineering. 131874 rows. 65 cols

# %%
df.club_position.unique()
# Out:
# array(['RW', 'ST', 'LW', 'RCM', 'GK', 'CF', 'CDM', 'LCB', 'RDM', 'RS',
#        'LCM', 'SUB', 'CAM', 'RCB', 'LDM', 'LB', 'RB', 'LM', 'RM', 'CB',
#        'LS', 'RES', 'RWB', 'RF', 'CM', 'LWB', 'LAM', 'LF', 'RAM'],
#       dtype=object)

# %%
df.club_position.nunique()
# Out:
# 29

# %%
df.head()
# Out:
#    sofifa_id         short_name player_positions  overall  potential  \
# 0     158023           L. Messi       RW, ST, CF       93         93
# 1     188545     R. Lewandowski               ST       92         92
# 2      20801  Cristiano Ronaldo           ST, LW       91         91
# 3     190871          Neymar Jr          LW, CAM       91         91
# 4     192985       K. De Bruyne          CM, CAM       91         91
#
#      value_eur  wage_eur  age  height_cm  weight_kg  ...  \
# 0   78000000.0  320000.0   34        170         72  ...
# 1  119500000.0  270000.0   32        185         81  ...
# 2   45000000.0  270000.0   36        187         83  ...
# 3  129000000.0  270000.0   29        175         68  ...
# 4  125500000.0  350000.0   30        181         70  ...
#
#    defending_standing_tackle defending_sliding_tackle goalkeeping_diving  \
# 0                         35                       24                  6
# ...

# %%
df.loc[df['short_name'] == 'Neymar Jr']
# Out:
#        sofifa_id short_name player_positions  overall  potential    value_eur  \
# 3         190871  Neymar Jr          LW, CAM       91         91  129000000.0
# 19242     190871  Neymar Jr          LW, CAM       91         91  132000000.0
# 38185     190871  Neymar Jr          LW, CAM       92         92  105500000.0
#
#        wage_eur  age  height_cm  weight_kg  ...  defending_standing_tackle  \
# 3      270000.0   29        175         68  ...                         32
# 19242  270000.0   28        175         68  ...                         30
# 38185  290000.0   27        175         68  ...                         26
#
#       defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 3                           29                  9                    9
# 19242                       29                  9                    9
# 38185                       29                  9                    9
#
# ...

# %%
df.loc[df['short_name'] == 'Cristiano Ronaldo']
# Out:
#         sofifa_id         short_name player_positions  overall  potential  \
# 2           20801  Cristiano Ronaldo           ST, LW       91         91
# 19240       20801  Cristiano Ronaldo           ST, LW       92         92
# 38184       20801  Cristiano Ronaldo           ST, LW       93         93
# 56666       20801  Cristiano Ronaldo           ST, LW       94         94
# 74751       20801  Cristiano Ronaldo           LW, ST       94         94
# 92705       20801  Cristiano Ronaldo       LW, LM, ST       94         94
# 110302      20801  Cristiano Ronaldo           LW, LM       93         93
# 125925      20801  Cristiano Ronaldo           LW, LM       92         92
#
#          value_eur  wage_eur  age  height_cm  weight_kg  ...  \
# 2       45000000.0  270000.0   36        187         83  ...
# 19240   63000000.0  220000.0   35        187         83  ...
# 38184   58500000.0  410000.0   34        187         83  ...
# ...
